# %%
import sys
import os
def get_FACEGroup_Directory():
    """Get the path of the 'FACEGroup-Feasible-and-Actionable-Counterfactual-Explanations-for-Group-Fairness-Auditing' directory."""
    current_dir = os.getcwd()
    target_dir = 'FACEGroup-Feasible-and-Actionable-Counterfactual-Explanations-for-Group-Fairness-Auditing'
    
    while os.path.basename(current_dir) != target_dir:
        current_dir = os.path.dirname(current_dir)
        if current_dir == os.path.dirname(current_dir):
            return None
        
    return current_dir

def get_system_slash():
    """Get the system-specific directory separator."""
    return os.sep

FACEGroup_DIR = get_FACEGroup_Directory()
sys.path.append(FACEGroup_DIR)
sep = get_system_slash()
sys.path.append(FACEGroup_DIR + get_system_slash() + 'src')
from main import *
from metrics import attribution_analysis, plot_feature_frequency, plot_feature_frequency_per_wcc
# Out:
# 2025-03-14 20:40:36.857291: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-14 20:40:36.868509: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-14 20:40:36.871843: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-14 20:40:36.881553: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Adult

# %%
datasetName="Adult"
epsilon=0.4
per_group_per_subgroup="per_group"
bandwith_approch='mean_scotts_rule'
freq_threshold=50
max_d=1.05
k=12

# %%
freq_threshold=0
action_frequency_g0, action_frequency_g1 = attribution_analysis(datasetName=datasetName, epsilon=epsilon, per_group_per_subgroup="per_subgroup",\
                         bandwith_approch=bandwith_approch, max_d=max_d, k=k, freq_threshold=0)

# %%
plot_feature_frequency_per_wcc(datasetName, action_frequency_g0, action_frequency_g1, sx=7, sy=4, params_size=18, freq_threshold=freq_threshold)
# Out:
# WCC: 0
# WCC: 1
# WCC: 8
# WCC: 410
# WCC: 412
# WCC: 413
# WCC: 415
# WCC: 434

# %% [markdown]
# # AdultCalifornia

# %%
datasetName="AdultCalifornia"
epsilon=0.7
per_group_per_subgroup="per_group"
bandwith_approch='mean_scotts_rule'
freq_threshold=50
max_d=1.86
k=75
action_frequency_g0, action_frequency_g1 = attribution_analysis(datasetName=datasetName, epsilon=epsilon, per_group_per_subgroup="per_group",\
                         bandwith_approch=bandwith_approch, max_d=max_d, k=k, freq_threshold=50)

# %%
plot_feature_frequency(datasetName, action_frequency_g0, action_frequency_g1, sx=8, sy=6, freq_threshold=freq_threshold)

# %% [markdown]
# # AdultLouisiana

# %%
datasetName="AdultLouisiana"
epsilon=0.5
per_group_per_subgroup="per_group"
bandwith_approch='mean_scotts_rule'
freq_threshold=50
max_d=1.29
k=35
action_frequency_g0, action_frequency_g1 = attribution_analysis(datasetName=datasetName, epsilon=epsilon, per_group_per_subgroup="per_group",\
                         bandwith_approch=bandwith_approch, max_d=max_d, k=k, freq_threshold=50)

# %%
plot_feature_frequency(datasetName, action_frequency_g0, action_frequency_g1, sx=8, sy=6, freq_threshold=freq_threshold)

# %% [markdown]
# # Student

# %%
datasetName="Student"
epsilon=3
per_group_per_subgroup="per_group"
bandwith_approch='optimal'
freq_threshold=50
max_d=3.62
k=2
action_frequency_g0, action_frequency_g1 = attribution_analysis(datasetName=datasetName, epsilon=epsilon, per_group_per_subgroup="per_group",\
                         bandwith_approch=bandwith_approch, max_d=max_d, k=k, freq_threshold=50)

# %%
plot_feature_frequency(datasetName, action_frequency_g0, action_frequency_g1, sx=8, sy=6, freq_threshold=freq_threshold)

# %% [markdown]
# # Compas

# %%
datasetName="Compas"
epsilon=1.1
per_group_per_subgroup="per_group"
bandwith_approch='optimal'
freq_threshold=50
max_d=1.23
k=5
action_frequency_g0, action_frequency_g1 = attribution_analysis(datasetName=datasetName, epsilon=epsilon, per_group_per_subgroup="per_group",\
                         bandwith_approch=bandwith_approch, max_d=max_d, k=k, freq_threshold=50)

# %%
plot_feature_frequency(datasetName, action_frequency_g0, action_frequency_g1, sx=8, sy=6, freq_threshold=freq_threshold)

# %% [markdown]
# # GermanCredit

# %%
datasetName="GermanCredit"
epsilon=3.1
per_group_per_subgroup="per_group"
bandwith_approch='optimal'
freq_threshold=50
max_d=2.51
k=6
action_frequency_g0, action_frequency_g1 = attribution_analysis(datasetName=datasetName, epsilon=epsilon, per_group_per_subgroup="per_group",\
                         bandwith_approch=bandwith_approch, group_identifier="Sex", max_d=max_d, k=k, freq_threshold=50)

# %%
plot_feature_frequency(datasetName, action_frequency_g0, action_frequency_g1, sx=8, sy=6, freq_threshold=freq_threshold)

# %% [markdown]
# # Heloc

# %%
datasetName="Heloc"
epsilon=1.3
per_group_per_subgroup="per_group"
bandwith_approch='optimal'
freq_threshold=50
max_d=1.56
k=6
action_frequency_g0, action_frequency_g1 = attribution_analysis(datasetName=datasetName, epsilon=epsilon, per_group_per_subgroup="per_group",\
                         bandwith_approch=bandwith_approch, group_identifier="MaxDelqEver", group_identifier_value=5, max_d=max_d, k=k, freq_threshold=50)

# %%
plot_feature_frequency(datasetName, action_frequency_g0, action_frequency_g1, sx=8, sy=6, freq_threshold=freq_threshold)
