# %%
import sys
import os
def get_FACEGroup_Directory():
    """Get the path of the 'FACEGroup-Feasible-and-Actionable-Counterfactual-Explanations-for-Group-Fairness-Auditing' directory."""
    current_dir = os.getcwd()
    target_dir = 'FACEGroup-Feasible-and-Actionable-Counterfactual-Explanations-for-Group-Fairness-Auditing'
    
    while os.path.basename(current_dir) != target_dir:
        current_dir = os.path.dirname(current_dir)
        if current_dir == os.path.dirname(current_dir):
            return None
        
    return current_dir

def get_system_slash():
    """Get the system-specific directory separator."""
    return os.sep

FACEGroup_DIR = get_FACEGroup_Directory()
sys.path.append(FACEGroup_DIR)
sep = get_system_slash()
sys.path.append(FACEGroup_DIR + get_system_slash() + 'src')
from main import *
# Out:
# 2025-03-15 02:28:08.596369: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-15 02:28:08.596404: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-15 02:28:08.597574: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-15 02:28:08.603526: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Adult dataset

# %%
from test_utils import *
datasetName = "Adult"
max_d = 1000000000
results = face_comparison(datasetName=datasetName, epsilon=0.4, tp=0.5, td=0.001, bandwith_approch="mean_scotts_rule", classifier="xgb",\
                    group_identifier='sex', upper_limit_for_k=15, group_identifier_value=None, \
                    skip_model_training=True, skip_bandwith_calculation=True, skip_graph_creation=True, skip_distance_calculation=True,\
                    max_d=max_d, representation=16)
face_dists = [results[k]['face_vector_distances'] for k in results]
gfce_dists = [results[k]['gfce_vector_distances'] for k in results]
face_wij = [results[k]['face_wij_distances'] for k in results]
gfce_wij = [results[k]['gfce_wij_distances'] for k in results]
k_values = list(results.keys())

# %%
face_dists, gfce_dists, face_wij, gfce_wij = None, None, None, None
import pickle
from test_utils import *
datasetName = "Adult"
max_d = 1000000000
with open(FACEGroup_DIR + sep + 'tmp' + sep + f'{datasetName}' + sep + f'{datasetName}_face_comparison.pkl', 'rb') as f:
    results = pickle.load(f)
face_dists = [results[k]['face_vector_distances'] for k in results]
gfce_dists = [results[k]['gfce_vector_distances'] for k in results]
face_wij = [results[k]['face_wij_distances'] for k in results]
gfce_wij = [results[k]['gfce_wij_distances'] for k in results]
k_values = list(results.keys())

# %%
face_plot(datasetName, face_dists, gfce_dists, face_wij, gfce_wij, "max_path_cost", max_d, k_values, 10, 6.4, 30, legend_inside=False)

# %% [markdown]
# # Adult-Louisiana dataset

# %%
from test_utils import *
datasetName = "AdultLouisiana"
max_d = 1000000000
results = face_comparison(datasetName=datasetName, epsilon=0.5, tp=0.5, td=0.001, bandwith_approch="optimal", classifier="xgb",\
                    group_identifier='sex', upper_limit_for_k=15, group_identifier_value=None, \
                    skip_model_training=True, skip_bandwith_calculation=True, skip_graph_creation=True, skip_distance_calculation=True,\
                    max_d=max_d, representation=16)
face_dists = [results[k]['face_vector_distances'] for k in results]
gfce_dists = [results[k]['gfce_vector_distances'] for k in results]
face_wij = [results[k]['face_wij_distances'] for k in results]
gfce_wij = [results[k]['gfce_wij_distances'] for k in results]
k_values = list(results.keys())

# %%
face_dists, gfce_dists, face_wij, gfce_wij = None, None, None, None
import pickle
from test_utils import *
datasetName = "AdultLouisiana"
max_d = 1000000000
with open(FACEGroup_DIR + sep + 'tmp' + sep + f'{datasetName}' + sep + f'{datasetName}_face_comparison.pkl', 'rb') as f:
    results = pickle.load(f)
face_dists = [results[k]['face_vector_distances'] for k in results]
gfce_dists = [results[k]['gfce_vector_distances'] for k in results]
face_wij = [results[k]['face_wij_distances'] for k in results]
gfce_wij = [results[k]['gfce_wij_distances'] for k in results]
k_values = list(results.keys())

# %%
face_plot(datasetName, face_dists, gfce_dists, face_wij, gfce_wij, "max_path_cost", max_d, k_values, 10, 6, 30, legend_inside=False, round_precision_wij=4, round_precision_v=2)

# %% [markdown]
# # Adult-California dataset

# %%
from test_utils import *
datasetName = "AdultCalifornia"
max_d = 1000000000
results = face_comparison(datasetName=datasetName, epsilon=0.7, tp=0.5, td=0.001, bandwith_approch="optimal", classifier="xgb",\
                    group_identifier='sex', upper_limit_for_k=15, group_identifier_value=None, \
                    skip_model_training=True, skip_bandwith_calculation=True, skip_graph_creation=True, skip_distance_calculation=True,\
                    max_d=max_d, representation=16)
face_dists = [results[k]['face_vector_distances'] for k in results]
gfce_dists = [results[k]['gfce_vector_distances'] for k in results]
face_wij = [results[k]['face_wij_distances'] for k in results]
gfce_wij = [results[k]['gfce_wij_distances'] for k in results]
k_values = list(results.keys())

# %%
face_dists, gfce_dists, face_wij, gfce_wij = None, None, None, None
import pickle
from test_utils import *
datasetName = "AdultCalifornia"
max_d = 1000000000
with open(FACEGroup_DIR + sep + 'tmp' + sep + f'{datasetName}' + sep + f'{datasetName}_face_comparison.pkl', 'rb') as f:
    results = pickle.load(f)
face_dists = [results[k]['face_vector_distances'] for k in results]
gfce_dists = [results[k]['gfce_vector_distances'] for k in results]
face_wij = [results[k]['face_wij_distances'] for k in results]
gfce_wij = [results[k]['gfce_wij_distances'] for k in results]
k_values = list(results.keys())

# %%
face_plot(datasetName, face_dists, gfce_dists, face_wij, gfce_wij, "max_path_cost", max_d, k_values, 10, 6, 30, legend_inside=False, round_precision_wij=5, round_precision_v=2)

# %% [markdown]
# # Student dataset

# %%
from test_utils import *
datasetName = "Student"
max_d = 1000000000
results = face_comparison(datasetName=datasetName, epsilon=3, bandwith_approch="optimal", classifier="xgb",\
                    group_identifier='sex', upper_limit_for_k=10, group_identifier_value=None, \
                    skip_model_training=True, skip_bandwith_calculation=True, skip_graph_creation=True, skip_distance_calculation=True,\
                    max_d=max_d, representation=64, steps=9)
face_dists = [results[k]['face_vector_distances'] for k in results]
gfce_dists = [results[k]['gfce_vector_distances'] for k in results]
face_wij = [results[k]['face_wij_distances'] for k in results]
gfce_wij = [results[k]['gfce_wij_distances'] for k in results]
k_values = list(results.keys())

# %%
face_plot(datasetName, face_dists, gfce_dists, face_wij, gfce_wij, "max_path_cost", max_d, k_values, 10, 6, 30, ax1_ylabel=True, ax2_ylabel=True, legend_inside=False)

# %% [markdown]
# # Compas dataset

# %%
from test_utils import *
datasetName = "Compas"
max_d = 1000000000
results = face_comparison(datasetName=datasetName, epsilon=1.1, bandwith_approch="optimal", classifier="xgb",\
                    group_identifier='sex', upper_limit_for_k=10, group_identifier_value=None, \
                    skip_model_training=True, skip_bandwith_calculation=True, skip_graph_creation=True, skip_distance_calculation=True,\
                    max_d=max_d, representation=64)
face_dists = [results[k]['face_vector_distances'] for k in results]
gfce_dists = [results[k]['gfce_vector_distances'] for k in results]
face_wij = [results[k]['face_wij_distances'] for k in results]
gfce_wij = [results[k]['gfce_wij_distances'] for k in results]
k_values = list(results.keys())

# %%
face_dists, gfce_dists, face_wij, gfce_wij = None, None, None, None
import pickle
from test_utils import *
datasetName = "Compas"
max_d = 1000000000
with open(FACEGroup_DIR + sep + 'tmp' + sep + f'{datasetName}' + sep + f'{datasetName}_face_comparison.pkl', 'rb') as f:
    results = pickle.load(f)
face_dists = [results[k]['face_vector_distances'] for k in results]
gfce_dists = [results[k]['gfce_vector_distances'] for k in results]
face_wij = [results[k]['face_wij_distances'] for k in results]
gfce_wij = [results[k]['gfce_wij_distances'] for k in results]
k_values = list(results.keys())

# %%
face_plot(datasetName, face_dists, gfce_dists, face_wij, gfce_wij, "max_path_cost", max_d, k_values, 10, 6, 30, ax1_ylabel=True, ax2_ylabel=True, legend_inside=True, legend_fontsize=22)

# %% [markdown]
# # GermanCredit

# %%
from test_utils import *
datasetName = "GermanCredit"
max_d = 1000000000
results = face_comparison(datasetName=datasetName, epsilon=3.1, bandwith_approch="optimal", classifier="xgb",\
                    group_identifier='Sex', upper_limit_for_k=10, group_identifier_value=None, \
                    skip_model_training=True, skip_bandwith_calculation=True, skip_graph_creation=True, skip_distance_calculation=True,\
                    max_d=max_d, representation=64)
face_dists = [results[k]['face_vector_distances'] for k in results]
gfce_dists = [results[k]['gfce_vector_distances'] for k in results]
face_wij = [results[k]['face_wij_distances'] for k in results]
gfce_wij = [results[k]['gfce_wij_distances'] for k in results]
k_values = list(results.keys())
# Out:
# /home/christos_fragk/FACEGroup-Feasible-and-Actionable-Counterfactual-Explanations-for-Group-Fairness-Auditing/src/dataLoader.py:61: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data_df = pd.read_csv(f"{FACEGroup_DIR}/data/GermanCredit.data", header=None, delim_whitespace = True)
# Data shape: (1000, 38)
# Feature columns: Index(['Existing-Account-Status', 'Month-Duration', 'Credit-Amount',
#        'Savings-Account', 'Present-Employment', 'Instalment-Rate', 'Sex',
#        'Guarantors', 'Residence', 'Property', 'Age', 'Installment', 'Housing',
#        'Existing-Credits', 'Job', 'Num-People', 'Telephone', 'Foreign-Worker',
#        'Credit-History_0', 'Credit-History_1', 'Credit-History_2',
#        'Credit-History_3', 'Credit-History_4', 'Purpose_0', 'Purpose_1',
#        'Purpose_2', 'Purpose_3', 'Purpose_4', 'Purpose_5', 'Purpose_6',
# ...

# %%
face_plot(datasetName, face_dists, gfce_dists, face_wij, gfce_wij, "max_path_cost", max_d, k_values, 10, 6.4, 30, legend_inside=False)

# %% [markdown]
# # HELOC

# %%
from test_utils import *
datasetName = "Heloc"
max_d = 1000000000
results = face_comparison(datasetName=datasetName, epsilon=1.3, bandwith_approch="optimal", classifier="xgb",\
                    group_identifier='MaxDelqEver', upper_limit_for_k=10, group_identifier_value=5, \
                    skip_model_training=True, skip_bandwith_calculation=True, skip_graph_creation=True, skip_distance_calculation=True,\
                    max_d=max_d, representation=64)
face_dists = [results[k]['face_vector_distances'] for k in results]
gfce_dists = [results[k]['gfce_vector_distances'] for k in results]
face_wij = [results[k]['face_wij_distances'] for k in results]
gfce_wij = [results[k]['gfce_wij_distances'] for k in results]
k_values = list(results.keys())

# %%
face_dists, gfce_dists, face_wij, gfce_wij = None, None, None, None
import pickle
from test_utils import *
datasetName = "Heloc"
max_d = 1000000000
with open(FACEGroup_DIR + sep + 'tmp' + sep + f'{datasetName}' + sep + f'{datasetName}_face_comparison.pkl', 'rb') as f:
    results = pickle.load(f)
face_dists = [results[k]['face_vector_distances'] for k in results]
gfce_dists = [results[k]['gfce_vector_distances'] for k in results]
face_wij = [results[k]['face_wij_distances'] for k in results]
gfce_wij = [results[k]['gfce_wij_distances'] for k in results]
k_values = list(results.keys())

# %%
face_plot(datasetName, face_dists, gfce_dists, face_wij, gfce_wij, "max_path_cost", max_d, k_values, 10, 6.4, 30, legend_inside=True, legend_fontsize=20, loc='center right')
